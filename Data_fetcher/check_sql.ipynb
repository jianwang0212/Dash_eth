# %%
import sqlite3
import pandas as pd
import settings
import datetime as dt

# %%
# trades check
exchanges = settings.exchanges
conn = sqlite3.connect('test.db')

for k, v in exchanges.items():
    exchange_name = k
    exchange = v
    table_name = exchange_name + "_trades"
    # print(df)
    print(pd.read_sql_query("SELECT * from {}".format(table_name),conn))
# Out:
#      index            utc                 time  \
# 0        0  1587566826553  2020-04-22 15:47:06
# 1        1  1587566826553  2020-04-22 15:47:06
# 2        2  1587566826553  2020-04-22 15:47:06
# 3        3  1587567287153  2020-04-22 15:54:47
# 4        4  1587621782248  2020-04-23 07:03:02
# ..     ...            ...                  ...
# 156      5  1588100057178  2020-04-28 19:54:17
# 157      6  1588100060962  2020-04-28 19:54:20
# 158      7  1588100071889  2020-04-28 19:54:31
# 159      8  1588100274338  2020-04-28 19:57:54
# 160      9  1588100274612  2020-04-28 19:57:54
#
#                                  trade_id  \
# 0    230b3317-84a8-11ea-b93c-0242ac11000b
# 1    230b3316-84a8-11ea-b93c-0242ac11000b
# 2    230b3315-84a8-11ea-b93c-0242ac11000b
# 3    35952f01-84a9-11ea-b93c-0242ac11000b
# 4    1730c764-8528-11ea-b93c-0242ac11000b
# ..                                    ...
# 156  a9437c06-8981-11ea-b93c-0242ac11000b
# 157  ab84e0a9-8981-11ea-b93c-0242ac11000b
# 158  b2083411-8981-11ea-b93c-0242ac11000b
# 159  2ab378bf-8982-11ea-b93c-0242ac11000b
# 160  2add47e6-8982-11ea-b93c-0242ac11000b
#
#                                  order_id   type takerOrMaker  side  \
# 0    230b3311-84a8-11ea-b93c-0242ac11000b  limit        taker   buy
# 1    230b3311-84a8-11ea-b93c-0242ac11000b  limit        taker   buy
# 2    230b3311-84a8-11ea-b93c-0242ac11000b  limit        taker   buy
# 3    35952eff-84a9-11ea-b93c-0242ac11000b  limit        taker   buy
# 4    1730c762-8528-11ea-b93c-0242ac11000b  limit        taker  sell
# ..                                    ...    ...          ...   ...
# 156  99dfaa89-8981-11ea-b93c-0242ac11000b  limit        maker   buy
# 157  99dfaa89-8981-11ea-b93c-0242ac11000b  limit        maker   buy
# 158  99dfaa89-8981-11ea-b93c-0242ac11000b  limit        maker   buy
# 159  221e0d5c-8982-11ea-b93c-0242ac11000b  limit        maker   buy
# 160  221e0d5c-8982-11ea-b93c-0242ac11000b  limit        maker   buy
#
#         amount   price   fee_fiat        fx   fee_pct exchange
# 0     0.372967  770.00   0.804119  4.190604  0.002800   bitbay
# 1     0.679029  770.00   1.463986  4.190604  0.002800   bitbay
# 2     0.018000  770.00   0.038816  4.190604  0.002801   bitbay
# 3    10.094257  765.70  21.641691  4.190604  0.002800   bitbay
# 4     0.026144  765.00   0.060000  4.190604  0.003000   bitbay
# ..         ...     ...        ...       ...       ...      ...
# 156   0.300000  830.15   0.448281  4.198094  0.001800   bitbay
# 157   0.090723  830.15   0.135572  4.198094  0.001800   bitbay
# 158   0.052275  830.15   0.078117  4.198094  0.001800   bitbay
# 159   0.373447  830.64   0.558365  4.198094  0.001800   bitbay
# 160   0.212206  830.64   0.317288  4.198094  0.001800   bitbay
#
# [161 rows x 14 columns]
#      index            utc                 time trade_id  order_id  type  \
# 0       49  1587816634000  2020-04-25 13:10:34  2703974  24634037  None
# 1       48  1587816679000  2020-04-25 13:11:19  2703975  24634037  None
# 2       47  1587816690000  2020-04-25 13:11:30  2703976  24634037  None
# 3       46  1587817149000  2020-04-25 13:19:09  2703987  24634180  None
# 4       45  1587819892000  2020-04-25 14:04:52  2704041  24634684  None
# ..     ...            ...                  ...      ...       ...   ...
# 197      1  1588083782000  2020-04-28 15:23:02  2709658  24716561  None
# 198      0  1588083846000  2020-04-28 15:24:06  2709659  24716561  None
# 199      0  1588085574000  2020-04-28 15:52:54  2709681  24717451  None
# 200      0  1588090051000  2020-04-28 17:07:31  2709762  24719853  None
# 201      0  1588092045000  2020-04-28 17:40:45  2709782  24720877  None
#
#     takerOrMaker  side      amount    price fee_fiat        fx   fee_pct  \
# 0           None   buy  0.03371073  2970000      300  15383.30  0.002996
# 1           None   buy  0.24098740  2970000        0  15383.30  0.000000
# 2           None   buy  0.02727000  2970000        0  15383.30  0.000000
# 3           None   buy  0.05091895  2973000        0  15383.30  0.000000
# 4           None   buy  0.23918718  2977000        0  15383.30  0.000000
# ..           ...   ...         ...      ...      ...       ...       ...
# 197         None  sell  0.01976754  3007000        0  15407.50  0.000000
# 198         None  sell  0.03021150  3007000        0  15407.50  0.000000
# 199         None  sell  3.83252075  3011000        0  15397.55  0.000000
# 200         None   buy  0.32000000  3002000        0  15405.75  0.000000
# 201         None   buy  0.93076970  3006000        0  15400.05  0.000000
#
#     exchange
# 0    indodax
# 1    indodax
# 2    indodax
# 3    indodax
# 4    indodax
# ..       ...
# 197  indodax
# 198  indodax
# 199  indodax
# 200  indodax
# 201  indodax
#
# [202 rows x 14 columns]

# %%
# bal & orderbook check 
for k, v in exchanges.items():
    exchange_name = k
    exchange = v
    table_name = exchange_name + "_bal_orderbook"
    df = pd.read_sql_query("SELECT * from {}".format(table_name),conn)
    print(pd.read_sql_query("SELECT * from {}".format(table_name),conn).tail())
# Out:
#       index               time           utc exchange     pair        fx  \
# 2120      0  20-04-28 19:26:01  1.588098e+09   bitbay  ETH/PLN  4.199435
# 2121      0  20-04-28 19:27:02  1.588098e+09   bitbay  ETH/PLN  4.199320
# 2122      0  20-04-28 19:28:02  1.588098e+09   bitbay  ETH/PLN  4.199210
# 2123      0  20-04-28 19:29:01  1.588099e+09   bitbay  ETH/PLN  4.199230
# 2124      0  20-04-28 19:31:02  1.588099e+09   bitbay  ETH/PLN  4.199220
#
#       bal_fiat_free  bal_fiat_used  bal_fiat_total  bal_eth_free  ...  \
# 2120       61798.80       56362.19       118160.99    122.296704  ...
# 2121       61798.80       56362.19       118160.99    122.296704  ...
# 2122       61798.87       56362.12       118160.99    122.296704  ...
# 2123       61798.87       56362.12       118160.99    122.296704  ...
# 2124       61798.80       56362.19       118160.99    122.296704  ...
#
#       1_bid_sz  2_bid_sz  3_bid_sz  4_bid_sz  5_bid_sz   1_ask_sz  2_ask_sz  \
# 2120  0.012005   0.72993  2.723913  3.762767  3.024096   7.996220   0.09942
# 2121  0.272870   0.72993  2.723913  3.762767  3.024096  10.880036   0.09942
# 2122  0.159470   0.72993  2.723913  3.762767  3.024096  11.239156   0.09942
# 2123  0.089447   0.72993  2.723913  3.762767  3.024096  30.810100   0.09942
# 2124  0.089447   0.72993  2.723913  3.762767  3.626506  11.693522  30.81010
#
#       3_ask_sz   4_ask_sz   5_ask_sz
# 2120   3.39030  67.361175  30.810100
# 2121   3.39030  67.361175  30.810100
# 2122   3.39030  30.810100  67.361175
# 2123   3.39030   8.245000  67.361175
# 2124   0.09942   8.245000  67.361175
#
# [5 rows x 32 columns]
#       index               time           utc exchange     pair        fx  \
# 1874      0  20-04-28 19:26:01  1.588098e+09  indodax  ETH/IDR  15397.55
# 1875      0  20-04-28 19:27:02  1.588098e+09  indodax  ETH/IDR  15397.55
# 1876      0  20-04-28 19:28:02  1.588098e+09  indodax  ETH/IDR  15397.55
# 1877      0  20-04-28 19:29:01  1.588099e+09  indodax  ETH/IDR  15397.55
# 1878      0  20-04-28 19:31:02  1.588099e+09  indodax  ETH/IDR  15397.55
#
#       bal_fiat_free  bal_fiat_used  bal_fiat_total  bal_eth_free  ...  \
# 1874    302108511.0            0.0     302108511.0     72.582924  ...
# 1875    265855611.0     36252900.0     302108511.0     72.582924  ...
# 1876    265855700.0     36252811.0     302108511.0     72.582924  ...
# 1877    265855496.0     36253015.0     302108511.0     72.582924  ...
# 1878    265855601.0     36252910.0     302108511.0     72.582924  ...
#
#        1_bid_sz   2_bid_sz   3_bid_sz    4_bid_sz    5_bid_sz  1_ask_sz  \
# 1874  46.715392  13.000940  13.547116   12.080300  459.147983  3.895864
# 1875  47.503355  13.000940  13.547116  470.191582    4.057919  0.099635
# 1876  42.669356   4.787000  13.000940   13.547116  458.107282  0.099635
# 1877   0.787963   5.246000  54.882334   13.547116  446.107282  9.997235
# 1878  45.013129   6.036954   0.610527   13.547116  457.151176  0.116961
#
#       2_ask_sz   3_ask_sz   4_ask_sz   5_ask_sz
# 1874  0.555292  11.428113   0.747180   9.236336
# 1875  3.895864   0.555292  11.428113   0.747180
# 1876  3.895864  10.452892   1.530513   0.747180
# 1877  3.895864   0.555292   1.530513  12.747180
# 1878  6.302484   9.897600   3.895864   0.555292
#
# [5 rows x 32 columns]

# %%
# merge check 
for k, v in exchanges.items():
    exchange_name = k
    exchange = v
    table_name = exchange_name + "_merge_td_bal_ods"
    df = pd.read_sql_query("SELECT * from {}".format(table_name),conn)
#     print(df)

# %%
def nearest(items, pivot):
    return min(items, key=lambda x: abs(x - pivot))
def cal_bal_usd(x):
    return (x['bal_fiat_total'] + x['bal_eth_total'] * x['1_bid_px'])/x['fx_x']

def pnl_to_string(amt, pct, rlt_amt, rlt_pct):
    amt =  '$' + amt.round().to_string().split()[1] + '/'
    pct =  (100 * pct).round(4).to_string().split()[1] + '%/'
    rlt_amt =  '$' + rlt_amt.round().to_string().split()[1] + '/'
    rlt_pct =  (100 * rlt_pct).round(4).to_string().split()[1] + '%'
    s= amt + pct + rlt_amt + rlt_pct
    return s

def pnl(df, time):
    df['time_x'] = df['time_x'].apply(lambda x: dt.datetime.strptime(x,"%y-%m-%d %H:%M:%S"))
    now = df['time_x'].iloc[-1]
    previous = now - dt.timedelta(hours = time)
    index = nearest(df['time_x'], previous)
    condition = df['time_x'] == index
    x_data = df[condition] # previous time data
    y_data = df.iloc[-1] # current time data
    x_bal = cal_bal_usd(x_data)
    y_bal = cal_bal_usd(y_data)
    amt = y_bal - x_bal
    pct = amt/x_bal
    mkt_amt = (y_data['1_bid_px'] - x_data['1_bid_px'])/x_data['fx_x']
    print(mkt_amt)
    mkt_pct = mkt_amt/x_data['1_bid_px']
    rlt_amt = amt - mkt_amt * 0.5
    rlt_pct = pct - mkt_pct * 0.5
    s = pnl_to_string(amt, pct, rlt_amt, rlt_pct)
    return y_data['1_bid_px']

# %%
s = pnl(df, 24000)
s
# Out:
# 0    2.795239
# dtype: float64
# 3007000.0

# %%
df['1_bid_px'][0] - df['1_bid_px'][1000]
# Out:
# -3000.0

# %%
# OpenOrder check 
for k, v in exchanges.items():
    exchange_name = k
    exchange = v
    table_name = exchange_name + "_open_order"
    # print(df)
    print(pd.read_sql_query("SELECT * from {}".format(table_name),conn))
# Out:
#       index               time           utc exchange     pair        fx  \
# 0         0  20-04-26 09:21:02  1.587889e+09   bitbay  ETH/PLN  4.190604
# 1         1  20-04-26 09:21:02  1.587889e+09   bitbay  ETH/PLN  4.190604
# 2         0  20-04-26 09:22:02  1.587889e+09   bitbay  ETH/PLN  4.190604
# 3         0  20-04-26 09:23:02  1.587889e+09   bitbay  ETH/PLN  4.190604
# 4         1  20-04-26 09:23:02  1.587889e+09   bitbay  ETH/PLN  4.190604
# ...     ...                ...           ...      ...      ...       ...
# 1106      0  20-04-27 06:18:01  1.587965e+09   bitbay  ETH/PLN  4.166320
# 1107      1  20-04-27 06:18:01  1.587965e+09   bitbay  ETH/PLN  4.166320
# 1108      2  20-04-27 06:18:01  1.587965e+09   bitbay  ETH/PLN  4.166320
# 1109      0  20-04-27 06:19:01  1.587965e+09   bitbay  ETH/PLN  4.166055
# 1110      1  20-04-27 06:19:01  1.587965e+09   bitbay  ETH/PLN  4.166055
#
#                               OpenOrder_id  OpenOrder_timestamp  \
# 0     3e5243f7-879f-11ea-b93c-0242ac11000b        1587892860335
# 1     3f7f524f-879f-11ea-b93c-0242ac11000b        1587892862308
# 2     5273eca6-879f-11ea-b93c-0242ac11000b        1587892894110
# 3     85e3092e-879f-11ea-b93c-0242ac11000b        1587892980402
# 4     86f27d62-879f-11ea-b93c-0242ac11000b        1587892982181
# ...                                    ...                  ...
# 1106  6edcc515-884e-11ea-b93c-0242ac11000b        1587968103701
# 1107  c0f43d54-884e-11ea-b93c-0242ac11000b        1587968241428
# 1108  d8cc5dcf-884e-11ea-b93c-0242ac11000b        1587968281432
# 1109  6edcc515-884e-11ea-b93c-0242ac11000b        1587968103701
# 1110  fcee6617-884e-11ea-b93c-0242ac11000b        1587968342053
#
#      OpenOrder_lastTradeTimestamp OpenOrder_symbol  ... OpenOrder_side  \
# 0                            None          ETH/PLN  ...            buy
# 1                            None          ETH/PLN  ...           sell
# 2                            None          ETH/PLN  ...           sell
# 3                            None          ETH/PLN  ...           sell
# 4                            None          ETH/PLN  ...            buy
# ...                           ...              ...  ...            ...
# 1106                         None          ETH/PLN  ...           sell
# 1107                         None          ETH/PLN  ...            buy
# 1108                         None          ETH/PLN  ...           sell
# 1109                         None          ETH/PLN  ...           sell
# 1110                         None          ETH/PLN  ...            buy
#
#      OpenOrder_price  OpenOrder_cost OpenOrder_average OpenOrder_amount  \
# 0             811.66            None              None          27.9775
# 1             824.85            None              None          31.8988
# 2             824.52            None              None          31.8988
# 3             824.85            None              None          31.8988
# 4             811.73            None              None          27.9751
# ...              ...             ...               ...              ...
# 1106          831.67            None              None           6.3651
# 1107          816.15            None              None          53.7726
# 1108          829.94            None              None           6.3651
# 1109          831.67            None              None           6.3651
# 1110          814.15            None              None          53.9047
#
#       OpenOrder_filled  OpenOrder_remaining  OpenOrder_status OpenOrder_fee  \
# 0                  0.0              27.9775              open          None
# 1                  0.0              31.8988              open          None
# 2                  0.0              31.8988              open          None
# 3                  0.0              31.8988              open          None
# 4                  0.0              27.9751              open          None
# ...                ...                  ...               ...           ...
# 1106               0.0               6.3651              open          None
# 1107               0.0              53.7726              open          None
# 1108               0.0               6.3651              open          None
# 1109               0.0               6.3651              open          None
# 1110               0.0              53.9047              open          None
#
#      OpenOrder_trades
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# ...               ...
# 1106             None
# 1107             None
# 1108             None
# 1109             None
# 1110             None
#
# [1111 rows x 21 columns]
#      index               time           utc exchange     pair       fx  \
# 0        0  20-04-26 09:21:02  1.587889e+09  indodax  ETH/IDR  15383.3
# 1        0  20-04-26 09:22:02  1.587889e+09  indodax  ETH/IDR  15383.3
# 2        0  20-04-26 09:23:02  1.587889e+09  indodax  ETH/IDR  15383.3
# 3        1  20-04-26 09:23:02  1.587889e+09  indodax  ETH/IDR  15383.3
# 4        0  20-04-26 09:24:02  1.587889e+09  indodax  ETH/IDR  15383.3
# ..     ...                ...           ...      ...      ...      ...
# 987      0  20-04-27 06:16:01  1.587965e+09  indodax  ETH/IDR  15544.5
# 988      1  20-04-27 06:16:01  1.587965e+09  indodax  ETH/IDR  15544.5
# 989      0  20-04-27 06:17:01  1.587965e+09  indodax  ETH/IDR  15544.5
# 990      1  20-04-27 06:17:01  1.587965e+09  indodax  ETH/IDR  15544.5
# 991      0  20-04-27 06:19:01  1.587965e+09  indodax  ETH/IDR  15547.7
#
#     OpenOrder_id  OpenOrder_timestamp OpenOrder_lastTradeTimestamp  \
# 0       24651185           1587892816                         None
# 1       24651185           1587892816                         None
# 2       24651185           1587892816                         None
# 3       24651206           1587892952                         None
# 4       24651185           1587892816                         None
# ..           ...                  ...                          ...
# 987     24674246           1587968114                         None
# 988     24674260           1587968131                         None
# 989     24674286           1587968219                         None
# 990     24674287           1587968219                         None
# 991     24674359           1587968341                         None
#
#     OpenOrder_symbol  ... OpenOrder_side OpenOrder_price  OpenOrder_cost  \
# 0            ETH/IDR  ...            buy       2963000.0      36558975.0
# 1            ETH/IDR  ...            buy       2963000.0      36558975.0
# 2            ETH/IDR  ...            buy       2963000.0      36558975.0
# 3            ETH/IDR  ...           sell       2979000.0      29159047.8
# 4            ETH/IDR  ...            buy       2963000.0      36558975.0
# ..               ...  ...            ...             ...             ...
# 987          ETH/IDR  ...           sell       2999000.0      39266806.7
# 988          ETH/IDR  ...            buy       2981000.0      26596482.0
# 989          ETH/IDR  ...            buy       2981000.0      26596482.0
# 990          ETH/IDR  ...           sell       2997000.0      39240620.1
# 991          ETH/IDR  ...            buy       2970000.0      26596350.0
#
#      OpenOrder_average OpenOrder_amount  OpenOrder_filled  \
# 0                 None          12.3385               0.0
# 1                 None          12.3385               0.0
# 2                 None          12.3385               0.0
# 3                 None           9.7882               0.0
# 4                 None          12.3385               0.0
# ..                 ...              ...               ...
# 987               None          13.0933               0.0
# 988               None           8.9220               0.0
# 989               None           8.9220               0.0
# 990               None          13.0933               0.0
# 991               None           8.9550               0.0
#
#      OpenOrder_remaining  OpenOrder_status OpenOrder_fee OpenOrder_trades
# 0                12.3385              open          None             None
# 1                12.3385              open          None             None
# 2                12.3385              open          None             None
# 3                 9.7882              open          None             None
# 4                12.3385              open          None             None
# ..                   ...               ...           ...              ...
# 987              13.0933              open          None             None
# 988               8.9220              open          None             None
# 989               8.9220              open          None             None
# 990              13.0933              open          None             None
# 991               8.9550              open          None             None
#
# [992 rows x 21 columns]
